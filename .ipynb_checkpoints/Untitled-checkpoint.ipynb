# %%
# !python -m torch.distributed.launch --nproc_per_node=2 --master_port 12345 main.py --dataset prcc --cfg configs/res50_cels_cal.yaml --gpu 0,1 --spr 1.0 --sacr 0.05 --rr 1.0
# Out:
# /root/miniconda3/lib/python3.8/site-packages/torch/distributed/launch.py:178: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# Config:
# -----------------------------------------
# AUG:
#   RC_PROB: 0.5
#   RE_PROB: 0.5
#   RF_PROB: 0.5
# DATA:
#   DATASET: prcc
#   HEIGHT: 384
#   NUM_INSTANCES: 8
#   NUM_WORKERS: 4
#   ROOT: /root/autodl-tmp/datasets
#   TEST_BATCH: 128
#   TRAIN_BATCH: 32
#   WIDTH: 192
# EVAL_MODE: False
# GPU: 0,1
# INFER:
#   SHOW_CC: True
# INFER_MODE: False
# LOSS:
#   CAL: cal
#   CLA_LOSS: crossentropylabelsmooth
#   CLA_M: 0.0
#   CLA_S: 16.0
#   CLOTHES_CLA_LOSS: cosface
#   EPSILON: 0.1
# ...
